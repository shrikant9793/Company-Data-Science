# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\hp\Documents\Python Scripts\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import os

url = "https://raw.githubusercontent.com/pydeveloperashish/Predicting-which-of-your-Employee-will-Quit-your-Company-Data-Science-Project/master/hr_data.csv"
hr_df = pd.read_csv(url, sep = ',')
hr_df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
hr_df.shape
# Out:
# (14999, 9)

# %%
hr_df.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='object')

# %%
hr_df.size
# Out:
# 134991

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
hr_df.describe().T
# Out:
#                          count          mean           std     min      25%  \
# employee_id            14999.0  45424.627575  25915.900127  1003.0  22872.5
# number_project         14999.0      3.803054      1.232592     2.0      3.0
# average_montly_hours   14999.0    201.050337     49.943099    96.0    156.0
# time_spend_company     14999.0      3.498233      1.460136     2.0      3.0
# Work_accident          14999.0      0.144610      0.351719     0.0      0.0
# left                   14999.0      0.238083      0.425924     0.0      0.0
# promotion_last_5years  14999.0      0.021268      0.144281     0.0      0.0
#
#                            50%      75%      max
# employee_id            45448.0  67480.5  99815.0
# number_project             4.0      5.0      7.0
# average_montly_hours     200.0    245.0    310.0
# time_spend_company         3.0      4.0     10.0
# Work_accident              0.0      0.0      1.0
# left                       0.0      0.0      1.0
# promotion_last_5years      0.0      0.0      1.0

# %%
hr_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
s_df = pd.read_excel(r"C:\Users\hp\Desktop\New folder\Python Object and Data Structure Basics\csv file\All Files\All Files\employee_satisfaction_evaluation.xlsx")
s_df.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
main_df = hr_df.set_index('employee_id').join(s_df.set_index('EMPLOYEE #'))
main_df
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# employee_id
# 1003                      2                   157                   3
# 1005                      5                   262                   6
# 1486                      7                   272                   4
# 1038                      5                   223                   5
# 1057                      2                   159                   3
# ...                     ...                   ...                 ...
# 87670                     2                   151                   3
# 87673                     2                   160                   3
# 87679                     2                   143                   3
# 87681                     6                   280                   4
# 87684                     2                   158                   3
#
#              Work_accident  left  promotion_last_5years department  salary  \
# employee_id
# 1003                     0     1                      0      sales     low
# 1005                     0     1                      0      sales  medium
# 1486                     0     1                      0      sales  medium
# 1038                     0     1                      0      sales     low
# 1057                     0     1                      0      sales     low
# ...                    ...   ...                    ...        ...     ...
# 87670                    0     1                      0    support     low
# 87673                    0     1                      0    support     low
# 87679                    0     1                      0    support     low
# 87681                    0     1                      0    support     low
# 87684                    0     1                      0    support     low
#
#              satisfaction_level  last_evaluation
# employee_id
# 1003                       0.38             0.53
# 1005                       0.80             0.86
# 1486                       0.11             0.88
# 1038                       0.72             0.87
# 1057                       0.37             0.52
# ...                         ...              ...
# 87670                      0.40             0.57
# 87673                      0.37             0.48
# 87679                      0.37             0.53
# 87681                      0.11             0.96
# 87684                      0.37             0.52
#
# [14999 rows x 10 columns]

# %%
hr_df.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='object')

# %%
s_df.columns
# Out:
# Index(['EMPLOYEE #', 'satisfaction_level', 'last_evaluation'], dtype='object')

# %%
print(main_df)
main_df= main_df.reset_index()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# employee_id
# 1003                      2                   157                   3
# 1005                      5                   262                   6
# 1486                      7                   272                   4
# 1038                      5                   223                   5
# 1057                      2                   159                   3
# ...                     ...                   ...                 ...
# 87670                     2                   151                   3
# 87673                     2                   160                   3
# 87679                     2                   143                   3
# 87681                     6                   280                   4
# 87684                     2                   158                   3
#
#              Work_accident  left  promotion_last_5years department  salary  \
# employee_id
# 1003                     0     1                      0      sales     low
# 1005                     0     1                      0      sales  medium
# 1486                     0     1                      0      sales  medium
# 1038                     0     1                      0      sales     low
# 1057                     0     1                      0      sales     low
# ...                    ...   ...                    ...        ...     ...
# 87670                    0     1                      0    support     low
# 87673                    0     1                      0    support     low
# 87679                    0     1                      0    support     low
# 87681                    0     1                      0    support     low
# 87684                    0     1                      0    support     low
#
#              satisfaction_level  last_evaluation
# employee_id
# 1003                       0.38             0.53
# 1005                       0.80             0.86
# 1486                       0.11             0.88
# 1038                       0.72             0.87
# 1057                       0.37             0.52
# ...                         ...              ...
# 87670                      0.40             0.57
# 87673                      0.37             0.48
# 87679                      0.37             0.53
# 87681                      0.11             0.96
# 87684                      0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 11 columns]

# %%
main_df.shape
# Out:
# (14999, 11)

# %%
main_df.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary', 'satisfaction_level', 'last_evaluation'],
#       dtype='object')

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
main_df[main_df.isnull().any(axis= 1)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# 352           3150               4                   262                   6
# 376           3250               4                   296                   2
# 402           3405               5                   275                   5
# 427          78130               3                   180                   4
# 442           3635               5                   229                   5
# 468           3755               5                   245                   5
# 543           4150               5                   237                   5
# 892          43615               4                   276                   5
# 1588         42185               5                   264                   5
# 1934         11895               4                   225                   5
# 2343         14170               3                   115                   2
# 2743         16445               5                   149                   2
# 3170         18980               5                   186                   2
# 3609         21580               3                   263                   2
# 3776         22555               4                   214                   3
# 4122         24505               3                   192                   3
# 4740         27950               3                   253                   3
# 5028         29640               4                   180                   4
# 6453         38090               5                   166                   2
# 7005         41535               4                   150                   3
# 7516         44460               4                   264                   3
# 8630         50960               4                   167                   3
# 9455         55770               4                   270                   3
# 9901         58630               5                   252                   3
# 10647        62595               4                   165                   3
# 10962        64350               5                   233                   3
# 11575        20215               3                   192                   7
# 11967        70005               3                   148                   3
# 12422        72475               5                   257                   5
# 12853        74880               3                   136                   2
# 13482        78780               3                   207                   7
# 13925        81315               3                   133                   3
#
#        Work_accident  left  promotion_last_5years   department  salary  \
# 18                 1     1                      1        sales     low
# 19                 0     1                      0        sales     low
# 33                 0     1                      0           hr     low
# 53                 0     1                      0      support     low
# 72                 0     1                      0  product_mng    high
# 92                 0     1                      0        sales     low
# 107                0     1                      0   accounting  medium
# 120                1     1                      0    technical     low
# 137                0     1                      0   management     low
# 175                0     1                      0        sales     low
# 191                1     1                      0    technical  medium
# 352                0     1                      0      support     low
# 376                0     1                      0           IT  medium
# 402                0     1                      0        sales     low
# 427                0     1                      0    technical  medium
# 442                0     1                      0   management     low
# 468                0     1                      0        sales     low
# 543                0     1                      0        sales  medium
# 892                0     1                      0      support     low
# 1588               0     1                      0           IT  medium
# 1934               0     1                      0        sales  medium
# 2343               1     0                      0      support     low
# 2743               0     0                      0        RandD     low
# 3170               0     0                      0    technical  medium
# 3609               1     0                      0        sales  medium
# 3776               0     0                      0    technical  medium
# 4122               0     0                      0    marketing    high
# 4740               0     0                      0    marketing  medium
# 5028               0     0                      0  product_mng  medium
# 6453               0     0                      0    technical    high
# 7005               0     0                      0    technical     low
# 7516               0     0                      0    technical     low
# 8630               1     0                      0    technical     low
# 9455               0     0                      0  product_mng     low
# 9901               0     0                      0      support  medium
# 10647              0     0                      0    technical     low
# 10962              0     0                      0      support     low
# 11575              0     0                      0   management    high
# 11967              0     0                      0           IT     low
# 12422              0     1                      0    technical  medium
# 12853              0     0                      0           hr    high
# 13482              0     0                      1   management  medium
# 13925              0     0                      0        sales  medium
#
#        satisfaction_level  last_evaluation
# 18                    NaN              NaN
# 19                    NaN             0.89
# 33                    NaN              NaN
# 53                    NaN              NaN
# 72                    NaN              NaN
# 92                    NaN              NaN
# 107                   NaN              NaN
# 120                   NaN              NaN
# 137                   NaN              NaN
# 175                   NaN              NaN
# 191                  0.92              NaN
# 352                   NaN             0.91
# 376                  0.56              NaN
# 402                   NaN             1.00
# 427                   NaN             0.60
# 442                  0.77              NaN
# 468                   NaN             0.92
# 543                  0.89              NaN
# 892                  0.74              NaN
# 1588                  NaN             0.81
# 1934                 0.78              NaN
# 2343                  NaN             0.97
# 2743                 0.62              NaN
# 3170                  NaN              NaN
# 3609                 0.95              NaN
# 3776                  NaN             0.68
# 4122                 0.86              NaN
# 4740                  NaN             0.95
# 5028                 0.64              NaN
# 6453                  NaN             0.78
# 7005                 0.82              NaN
# 7516                  NaN             0.97
# 8630                 0.90              NaN
# 9455                  NaN             0.88
# 9901                 0.92              NaN
# 10647                 NaN             0.69
# 10962                0.65              NaN
# 11575                 NaN              NaN
# 11967                0.82              NaN
# 12422                 NaN             1.00
# 12853                 NaN             0.70
# 13482                0.58              NaN
# 13925                 NaN             0.75

# %%
main_df.isnull().sum()
# Out:
# employee_id               0
# number_project            0
# average_montly_hours      0
# time_spend_company        0
# Work_accident             0
# left                      0
# promotion_last_5years     0
# department                0
# salary                    0
# satisfaction_level       27
# last_evaluation          27
# dtype: int64

# %%
main_df.fillna(main_df.mean(), inplace=True)

# %%
main_df.isnull().sum()
# Out:
# employee_id              0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# satisfaction_level       0
# last_evaluation          0
# dtype: int64

# %%
main_df.loc[main_df['employee_id'] == 1340]
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 53         1340               2                   132                   3
#
#     Work_accident  left  promotion_last_5years department salary  \
# 53              0     1                      0    support    low
#
#     satisfaction_level  last_evaluation
# 53             0.61283         0.716125

# %%
main_df.drop(columns= 'employee_id', inplace= True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# RandD                  134   121                     27           487.80000
# accounting              96   204                     14           446.68283
# hr                      89   215                     15           442.53566
# management             103    91                     69           391.76566
# marketing              138   203                     43           530.62283
# product_mng            132   198                      0           559.19566
# sales                  587  1014                    100          2543.77981
# support                345   555                     20          1377.90849
# technical              381   697                     28          1653.37264
#
#              last_evaluation
# department
# IT                879.452250
# RandD             560.446125
# accounting        550.706125
# hr                524.006125
# management        456.234499
# marketing         613.946125
# product_mng       644.662250
# sales            2938.236749
# support          1611.534499
# technical        1961.930624

# %%
main_df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# RandD             0.170267  0.153748               0.034307
# accounting        0.125163  0.265971               0.018253
# hr                0.120433  0.290934               0.020298
# management        0.163492  0.144444               0.109524
# marketing         0.160839  0.236597               0.050117
# product_mng       0.146341  0.219512               0.000000
# sales             0.141787  0.244928               0.024155
# support           0.154778  0.248991               0.008973
# technical         0.140074  0.256250               0.010294
#
#              satisfaction_level  last_evaluation
# department
# IT                     0.617908         0.716750
# RandD                  0.619822         0.712130
# accounting             0.582377         0.718000
# hr                     0.598830         0.709075
# management             0.621850         0.724182
# marketing              0.618442         0.715555
# product_mng            0.619951         0.714703
# sales                  0.614440         0.709719
# support                0.618173         0.722985
# technical              0.607858         0.721298

# %%
main_df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
def plot_corr(df, size = 10):
    
    corr= df.corr()
    fig, ax=plt.subplots(figsize=(size,size))
    ax.legend()
    cax= ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation= 'vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    
    
plot_corr(main_df)
# Out:
# No handles with labels found to put in legend.

# %%
with sns.color_palette('muted'):
    sns.countplot(x=main_df['left'])

# %%
main_df.left.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
main_df.left.value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
sns.barplot(x='left', y= 'satisfaction_level', data= main_df )
# Out:
# <AxesSubplot:xlabel='left', ylabel='satisfaction_level'>

# %%
sns.barplot(x= 'promotion_last_5years', y = 'satisfaction_level', data= main_df, hue= 'left')
# Out:
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='satisfaction_level'>

# %%
sns.pairplot(main_df, hue= 'left')
# Out:
# C:\Users\hp\Documents\Python Scripts\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\hp\Documents\Python Scripts\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\hp\Documents\Python Scripts\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\hp\Documents\Python Scripts\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
y = main_df[['department', 'salary']]
y
# Out:
#       department  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support     low
# 14995    support     low
# 14996    support     low
# 14997    support     low
# 14998    support     low
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

main_df['salary'] = le.fit_transform(main_df['salary'])

# %%
main_df['salary']
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: salary, Length: 14999, dtype: int32

# %%
main_df.head()
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
# 3               5                   223                   5              0
# 4               2                   159                   3              0
#
#    left  promotion_last_5years department  salary  satisfaction_level  \
# 0     1                      0      sales       1                0.38
# 1     1                      0      sales       2                0.80
# 2     1                      0      sales       2                0.11
# 3     1                      0      sales       1                0.72
# 4     1                      0      sales       1                0.37
#
#    last_evaluation
# 0             0.53
# 1             0.86
# 2             0.88
# 3             0.87
# 4             0.52

# %%
main_df['department'] = le.fit_transform(main_df['department'])

# %%
main_df.head()
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
# 3               5                   223                   5              0
# 4               2                   159                   3              0
#
#    left  promotion_last_5years  department  salary  satisfaction_level  \
# 0     1                      0           7       1                0.38
# 1     1                      0           7       2                0.80
# 2     1                      0           7       2                0.11
# 3     1                      0           7       1                0.72
# 4     1                      0           7       1                0.37
#
#    last_evaluation
# 0             0.53
# 1             0.86
# 2             0.88
# 3             0.87
# 4             0.52

# %%
X = main_df.drop(['left'], axis= 1)
y = main_df.left

# %%
X
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  promotion_last_5years  department  salary  \
# 0                  0                      0           7       1
# 1                  0                      0           7       2
# 2                  0                      0           7       2
# 3                  0                      0           7       1
# 4                  0                      0           7       1
# ...              ...                    ...         ...     ...
# 14994              0                      0           8       1
# 14995              0                      0           8       1
# 14996              0                      0           8       1
# 14997              0                      0           8       1
# 14998              0                      0           8       1
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 9 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state= 89)

scores_dict = {}

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)
prediction_dt = dt.predict(X_test)

accuracy_dt = accuracy_score(y_test, prediction_dt)*100

# %%
print('Accuracy_score : ', accuracy_dt)
scores_dict['DecisionTreeClassifier'] = accuracy_dt

print(classification_report(y_test, prediction_dt))
# Out:
# Accuracy_score :  97.88888888888889
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      3432
#            1       0.95      0.96      0.96      1068
#
#     accuracy                           0.98      4500
#    macro avg       0.97      0.97      0.97      4500
# weighted avg       0.98      0.98      0.98      4500

# %%
Category = ['Employee will stay', 'Employee will leave']
Category
# Out:
# ['Employee will stay', 'Employee will leave']

# %%
custom_dt = [[1,500,3,6,0,0.90,0.89,1,8]]
custom_dt
# Out:
# [[1, 500, 3, 6, 0, 0.9, 0.89, 1, 8]]

# %%
print(int(dt.predict(custom_dt)))
# Out:
# 1

# %%
Category[int(dt.predict(custom_dt))]
# Out:
# 'Employee will leave'

# %%
dt.feature_importances_
# Out:
# array([1.05390263e-01, 9.33723560e-02, 1.38945492e-01, 2.48412044e-03,
#        1.56801351e-04, 1.26644845e-02, 4.44540046e-03, 4.97696199e-01,
#        1.44844883e-01])

# %%
feature_importances = pd.DataFrame(dt.feature_importances_, index=X_train.columns, columns=['Importance']).sort_values('Importance', ascending= False)

# %%
feature_importances
# Out:
#                        Importance
# satisfaction_level       0.497696
# last_evaluation          0.144845
# time_spend_company       0.138945
# number_project           0.105390
# average_montly_hours     0.093372
# department               0.012664
# salary                   0.004445
# Work_accident            0.002484
# promotion_last_5years    0.000157

# %%
from sklearn.preprocessing import StandardScaler

# %%
print(list(main_df.columns))
# Out:
# ['number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years', 'department', 'salary', 'satisfaction_level', 'last_evaluation']

# %%
num_features = list(main_df.columns)
for x in ['salary', 'department', 'left']:
    num_features.remove(x)
    
    
sc = StandardScaler()

X_train_std = sc.fit_transform(X_train[num_features])
X_test_std = sc.transform(X_test[num_features])

# %%
from sklearn.neighbors import KNeighborsClassifier


k_range= range(1,26)
scores={}
scores_list=[]
bestk= 0
h_score = 0


for i in range(1,26):
    clf = KNeighborsClassifier(n_neighbors= i).fit(X_train_std, y_train)
    pred = clf.predict(X_test_std)
    scores[i]= accuracy_score(y_test, pred)
    if scores[i]> h_score:
        h_score = scores[i]
        bestk = i
    scores_list.append(scores[i])
    
print('Best k is {} with score : {}'.format(bestk, h_score))
# Out:
# Best k is 1 with score : 0.98

# %%
knn = KNeighborsClassifier(n_neighbors=bestk)
knn.fit(X_train_std, y_train)
prediction_knn= knn.predict(X_test_std)
accuracy_knn = accuracy_score(y_test, prediction_knn)*100
print(classification_report(y_test, prediction_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      3432
#            1       0.94      0.97      0.96      1068
#
#     accuracy                           0.98      4500
#    macro avg       0.97      0.98      0.97      4500
# weighted avg       0.98      0.98      0.98      4500

# %%
plt.plot(k_range,scores_list)

# %%
from sklearn.svm import SVC
model = SVC().fit(X_train_std,y_train)
pred = model.predict(X_test_std)
svc_accuracy = accuracy_score(y_test,pred)*100
print("Accuracy score : ", svc_accuracy)
scores_dict['SVC'] = svc_accuracy
print(classification_report(y_test, pred))
# Out:
# Accuracy score :  96.53333333333333
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      3432
#            1       0.94      0.91      0.93      1068
#
#     accuracy                           0.97      4500
#    macro avg       0.96      0.95      0.95      4500
# weighted avg       0.97      0.97      0.97      4500

# %%
from lightgbm import LGBMClassifier

# %%
model = LGBMClassifier(learning_rate= 0.03, n_estimators = 1000).fit(X_train_std, y_train)
pred = model.predict(X_test_std)
LGBM_accuracy = accuracy_score(y_test, pred)*100
print('Accuracy Score : ', LGBM_accuracy)
scores_dict['LGBMClassifier'] = LGBM_accuracy
# Out:
# Accuracy Score :  99.13333333333333

# %%
algo_name = list(scores_dict.keys())
accuracy_list = list(scores_dict.values())


sns.set(rc= {'figure.figsize': (12.4,6.5)})
with sns.color_palette('muted'):
    sns.barplot(x= algo_name, y= accuracy_list)
